# %% [markdown]
# ## Hello World of Quantum Computing using IBMQ

# %%
from qiskit import *

# %%
qr = QuantumRegister(2)

# %%
cr = ClassicalRegister(2)

# %%
circuit  = QuantumCircuit(qr, cr)

# %%
# %matplotlib inline

# %%
# Matplotlib Drawing
circuit.draw(output='mpl')

# %%
circuit.h(qr[0]) # Hadamard Gate

# %%
circuit.draw(output='mpl')

# %%
circuit.cx(qr[0],qr[1]) # logical if operation in Quantum circuit

# %%
circuit.draw(output='mpl')

# %%
circuit.measure(qr,cr)

# %%
circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')

# %%
result = execute(circuit, backend = simulator).result()

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result.get_counts(circuit))

# %%
from qiskit import IBMQ

# %%
IBMQ.save_account('015ec3093019f57b1d424a0ce5755f98f5e7155a4f1f8ea586dce9ffdf3964ddd30cc9935b68b8e6c56ef355c0d9a93f2099bfc06601cf5f73ce298c0241aa05')
# Out:
# configrc.store_credentials:WARNING:2020-08-07 21:04:03,572: Credentials already present. Set overwrite=True to overwrite.

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider = IBMQ.get_provider('ibm-q')

# %%
qcomp = provider.get_backend('ibmq_16_melbourne')

# %%
job = execute(circuit, backend=qcomp)

# %%
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
ibm_result = job.result()

# %%
plot_histogram(ibm_result.get_counts(circuit))
